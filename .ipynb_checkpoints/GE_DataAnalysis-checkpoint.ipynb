# %%
import requests
import json
import csv
import time

# %%
def fetch_item_price(item_id):
    url = base_url + str(item_id)
    response = requests.get(url, headers={
        'User-Agent': '@el on discord'
    })
    response.raise_for_status()  # Raise an HTTPError for bad responses (4xx and 5xx)
    
    return response.json()    
    
 #   all_data = []
  #  item_data = data.get("data", {}).get(str(item_id), {})

   # if not item_data:
    #    print(f"Item ID {item_id} not found in the API response.")
     #   return None

    #return {
     #   "id": item_id,
      #  "high": item_data.get("avgHighPrice"),
       # "low": item_data.get("avgLowPrice")
    #}

# %%
def save_to_csv(data, timestamp, filename="osrs_prices.csv"):
    """
    Appends data to a CSV file.

    Args:
        data (list): List of dictionaries containing item data.
        filename (str): The CSV file to write to.
    """
    file_exists = False
    try:
        # Check if the file already exists
        with open(filename, "r") as file:
            file_exists = True
    except FileNotFoundError:
        pass

    with open(filename, mode="a", newline="") as file:
        writer = csv.writer(file)
        if not file_exists:
            writer.writerow(["Item ID", "Timestamp", "Average High Price", "High Price Volume", "Low Price", "Low Price Volume"])  # Header row if file doesn't exist
        for id in data:
            writer.writerow([id, timestamp, data[str(id)]['avgHighPrice'], data[str(id)]['highPriceVolume'], data[str(id)]['avgLowPrice'], data[str(id)]['lowPriceVolume']])
    print(f"Data appended to {filename}")

# %%
#Can start at unix time: 1617321600
#86400 to forward the time by one day

# %%
base_url = "https://prices.runescape.wiki/api/v1/osrs/24h?timestamp="

print("Old School RuneScape Grand Exchange Price Scraper")

# Example: List of item IDs to fetch
timestamps = [1617321600]

for timestamp in timestamps:
    data = fetch_item_price(timestamp)['data']
    save_to_csv(data, timestamp)
    print(data)
    """for id in list(data['data']):
        print(id, ':', data['data'][str(id)])
    


    #if item_data:
    #    all_data.append(item_data)
     #   print(f"Item ID: {item_data['id']} - High Price: {item_data['high']} - Low Price: {item_data['low']}")
    #else:
     #   print(f"Failed to fetch data for item ID {item_id}")
        

#save_to_csv(all_data)"""
# Out:
# Old School RuneScape Grand Exchange Price Scraper
# Data appended to osrs_prices.csv
# {'2': {'avgHighPrice': 152, 'highPriceVolume': 20159216, 'avgLowPrice': 149, 'lowPriceVolume': 9254780}, '6': {'avgHighPrice': 183949, 'highPriceVolume': 243, 'avgLowPrice': 181150, 'lowPriceVolume': 681}, '8': {'avgHighPrice': 185536, 'highPriceVolume': 275, 'avgLowPrice': 182649, 'lowPriceVolume': 672}, '10': {'avgHighPrice': 185622, 'highPriceVolume': 273, 'avgLowPrice': 183357, 'lowPriceVolume': 704}, '12': {'avgHighPrice': 200667, 'highPriceVolume': 220, 'avgLowPrice': 195484, 'lowPriceVolume': 725}, '28': {'avgHighPrice': 31, 'highPriceVolume': 37, 'avgLowPrice': 4, 'lowPriceVolume': 24}, '30': {'avgHighPrice': 832, 'highPriceVolume': 915, 'avgLowPrice': 1012, 'lowPriceVolume': 87}, '36': {'avgHighPrice': 132, 'highPriceVolume': 1650, 'avgLowPrice': 95, 'lowPriceVolume': 81}, '39': {'avgHighPrice': 3, 'highPriceVolume': 251148, 'avgLowPrice': 3, 'lowPriceVolume': 89264}, '40': {'avgHighPrice': 16, 'highPriceVolume': 463129, 'avgLowPrice': 15, 'lowPriceVolume': 268351}, '41': {'avgHighPrice': 27, 'highPriceVolume': 458186, 'avgLowPrice': 30, 'lowPriceVolume': 389236}, '42': {'avgHighPrice': 38, 'highPriceVolume': 383453, 'av